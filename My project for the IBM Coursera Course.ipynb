# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My project for the IBM Coursera Course

# %% [markdown]
# In this prodjact I would like to shom my new knowleges and skills that I learned in Module 6.

# %% [markdown]
# __Objectives:__

# %% [markdown]
# - To show what Data science languages I know
# - To show what Data science libraries I know
# - To show what Data science tools I know
# - To show how create a table of the Data science tools
# - Evaluating arithmetic expressions in Python

# %% [markdown]
# I found out about the next data science languages:
# - Python
# - R
# - SQL

# %% [markdown]
# I learned about the following data science libraries:
# + Pandas
# + NumPy
# + Matplotlyb

# %% [markdown]
# I found out about the following Data Science tools:

# %% [markdown]
# | Data Science Tools |
# |---------------------|
# | Vs Code|
# |DBeaver|
# |Jupyter Notebook|

# %% [markdown]
# Now I now how to use arithmetic expressions in Python:

# %%
5*5+10
# Out:
# 35

# %% [markdown]
# I can convert 360 minutes to hours:

# %%
360/60
# Out:
# 6.0

# %% [markdown]
# ## Author

# %% [markdown]
# Nataliia Polovneva
